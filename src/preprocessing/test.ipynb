# %%
import pandas as pd

df = pd.read_csv(r"D:\FPT\AI\Major5\DPL302m\Project\StoryGen\data\training\orpo_dataset.csv")
df
# Out:
#                                                 prompt  \
# 0    \n                Dựa vào những ý chính theo d...
# 1    \n                Dựa vào những ý chính theo d...
# 2    \n                Dựa vào những ý chính theo d...
# 3    \n                Dựa vào những ý chính theo d...
# 4    \n                Dựa vào những ý chính theo d...
# ..                                                 ...
# 498  \n                Dựa vào những ý chính theo d...
# 499  \n                Dựa vào những ý chính theo d...
# 500  \n                Dựa vào những ý chính theo d...
# 501  \n                Dựa vào những ý chính theo d...
# 502  \n                Dựa vào những ý chính theo d...
#
#                                                 choose  \
# 0    Đó là một ngày tháng tư sáng lạnh, vừa lúc đồn...
# 1    Syme đã biến mất. Một buổi sáng anh không đến ...
# 2    Winston tỉnh dậy nước mắt đầm đìa. Julia ngái ...
# 3    Winston keo người vì mệt. Dùng chữ keo là đúng...
# ...

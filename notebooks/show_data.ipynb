# %%
import pandas as pd

# %%
df = pd.read_csv('/home/tandattran772/persional_project/StoryGen/data/processed/preference.csv')
df.head()
# Out:
#    Unnamed: 0                                      chapter_title  \
# 0           0  Harry Potter và Hội Phượng Hoàng (Quyển 5)/Chư...
# 1           1  Harry Potter và Hội Phượng Hoàng (Quyển 5)/Chư...
# 2           2  Harry Potter và Hội Phượng Hoàng (Quyển 5)/Chư...
# 3           3  Harry Potter và Hội Phượng Hoàng (Quyển 5)/Chư...
# 4           4  Harry Potter và Hội Phượng Hoàng (Quyển 5)/Chư...
#
#                                               chosen  \
# 0  Chương 33 - Chiến đấu và bay\nHarry không có ý...
# 1  Chương 15 - Thanh tra cao cấp cho trường Hogwa...
# 2  Chương 11 - Bài hát mới của cái mũ phân loại\n...
# 3  Chương 1 -\nNgày nắng nhất của mùa hè cho đến ...
# 4  Chương 3 - Đội bảo vệ đặc biệt\nCháu đã bị tấn...
#
#                                             rejected  \
# 0  Tóm tắt có sẵn:\n\n- Harry không biết kế hoạch...
# 1  Chương 15\n\nTrong khi bầu trời Hogwarts vẫn c...
# 2  Phần mở rộng của đoạn 1:\n\nHarry cố gắng giấu...
# ...

# %%
df['chapter_title'][0]
# Out:
# 'Harry Potter và Hội Phượng Hoàng (Quyển 5)/Chương 33 -- 34.txt'

# %%
print(df['chosen'][0])
# Out:
# Chương 33 - Chiến đấu và bay
# Harry không có ý tưởng gì về kế hoạch của Hermione, hoặc thậm chí không biết liệu cô bé có kế hoạch gì hay không. Nó đi sau cô bé một nửa bước chân khi tụi nó đi xuống hành lang ngoài văn phòng của Umbridge, biết rằng sẽ làm ụ (bây giờ ta có thể gọi là mụ được rồi nhỉ?) nghi ngờ nếu nó tỏ ra không biết nơi chúng sắp tới. Nó thậm chí không dám nói chuyện với cô bé, mụ Umbridge vẫn đang đi rất gần chúng đến nỗi nó có thể nghe thấy hơi thở không đều của mụ.
# Hermione đi xuống cầu thang dẫn vào Tiền Sảnh. Có tiếng ầm ĩ của những giọng nói to và tiếng lách cách của dao nĩa vọng ra từ cánh cửa lớn ở Đại Sảnh đường — dường như thật khó tin đối với Harry khi mà cách đó chỉ 20 feet, người ta đang tận hưởng bữa tối, ăn mừng khi thi xong, không phải bận tâm đến bất cứ thứ gì trên thế giới này…
# ...

# %%
print(df['prompt'][0])
# Out:
# Dựa vào bản tóm tắt của chương truyện theo dòng thời gian sau:
#
#     """
# - Harry không biết kế hoạch của Hermione và đi theo cô một nửa bước khi cả hai rời văn phòng của Umbridge.
# - Hermione dẫn đường xuống Tiền Sảnh, nơi tiếng nói ồn ào và tiếng dao nĩa từ Đại Sảnh Đường vọng ra.
# - Hermione và Umbridge đi qua cánh cửa gỗ sồi, xuống cầu thang đá vào buổi tối yên tĩnh.
# - Hermione và Umbridge tiếp tục vào rừng Cấm, Umbridge nghi ngờ rằng mục tiêu cuối cùng là lều của Hagrid.
# - Hermione chối bỏ và khẳng định mục tiêu nằm sâu trong rừng.
# - Harry và Hermione dẫn Umbridge vào rừng, không có đũa phép.
# - Hermione cố tình tạo ra tiếng động lớn, khiến Umbridge nghi ngờ.
# - Hermione tiết lộ rằng cô muốn nhân mã phát hiện họ.
# - Một mũi tên bay từ đâu đó, đánh dấu sự xuất hiện của nhân mã.
# - Harry, Hermione và Umbridge bị bao vây bởi khoảng năm mươi con nhân mã.
# - Hermione và Harry cố gắng hòa giải khi Umbridge và nhân mã đối đầu, nhưng không thành công.
# ...

# %%
print(df['reject'][0])
# Out:
# Tóm tắt có sẵn:
#
# - Harry không biết kế hoạch của Hermione và đi theo cô một nửa bước khi cả hai rời văn phòng của Umbridge.
# - Hermione dẫn đường xuống Tiền Sảnh, nơi tiếng nói ồn ào và tiếng dao nĩa từ Đại Sảnh Đường vọng ra.
# - Hermione và Umbridge đi qua cánh cửa gỗ sồi, xuống cầu thang đá vào buổi tối yên tĩnh.
#
# Chi tiết bổ sung:
#
# Harry bám theo Hermione từ một khoảng cách ngắn, cố gắng che giấu sự hiện diện của mình sau lớp áo choàng tàng hình. Anh thấy Hermione tiến về phía một cánh cửa gỗ sồi lớn trong Tiền Sảnh. Hermione mở toang cánh cửa, trang trọng bước vào, và Umbridge cũng đi theo sau.
#
# Cầu thang xoáy ốc đổ xuống bóng tối bên dưới, tỏa ra hơi ẩm và mùi đất ẩm ướt. Hermione dẫn đầu khi họ bước xuống cầu thang, từng bước chân vang vọng trong không gian trống trải. Umbridge cẩn thận theo sau, đôi mắt săm soi xung quanh.
#
# ...
